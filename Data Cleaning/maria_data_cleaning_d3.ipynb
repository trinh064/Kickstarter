# %%
import numpy as np
import pandas as pd
import random

# %%
# new data with unique features such as #of photos and videos
df_ks = pd.read_csv("../Data/kicktraq_kickstarter.csv")

# %% [markdown]
# # Cleaning

# %%
# 1. Replace status string with numbers in df_ks
cleanup_nums = {"status": {"Funding Unsuccessful": 0, "Funding Successful": 1, "Cancelled by Creator" : -1, "Cancelled by Kickstarter" : -1, "Suspended for DMCA" : -1}}
df_ks.replace(cleanup_nums, inplace=True)

# %%
df_ks['status'].value_counts()
# Out:
#  1    3835
#  0    2964
# -1    1229
# Name: status, dtype: int64

# %%
# Only keep 1 and 0 (successful and failed)

# %%
df_ks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8028 entries, 0 to 8027
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   avg_backers_per_pledge_tier   8028 non-null   float64
#  1   avg_pledge_amount_per_backer  8028 non-null   float64
#  2   campaign_end_date             8028 non-null   object
#  3   campaign_start_date           8028 non-null   object
#  4   category                      8028 non-null   object
#  5   city                          8028 non-null   object
#  6   description                   8027 non-null   object
#  7   description_length            8028 non-null   int64
#  8   dict_pledge_tier_backer       8028 non-null   object
#  9   featured_project              8028 non-null   int64
#  10  full_desc_len                 8028 non-null   int64
#  11  funding_currency              8028 non-null   object
# ...

# %% [markdown]
# ## Attempted to Merge with Joined

# %% [markdown]
# #### There are only 62 rows that correspond between the two tables, therefore it is not worth merging.

# %%
df_joined = pd.read_csv("../Data/Cleaned/joined_data.csv")

# %%
df_joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242630 entries, 0 to 242629
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   backers_count     242630 non-null  int64
#  1   blurb             242630 non-null  object
#  2   blurb_length      242630 non-null  int64
#  3   spotlight         242630 non-null  bool
#  4   staff_pick        242630 non-null  bool
#  5   location_state    242630 non-null  object
#  6   name              242630 non-null  object
#  7   category          242630 non-null  object
#  8   main_category     242630 non-null  object
#  9   state             242630 non-null  float64
#  10  country           242630 non-null  object
#  11  usd_pledged_real  242630 non-null  float64
#  12  usd_goal_real     242630 non-null  float64
#  13  launch_hour       242630 non-null  int64
#  14  launch_day        242630 non-null  int64
#  15  launch_month      242630 non-null  int64
# ...

# %%
df_ks_2 = df_ks.drop(columns=['state','category'])
df_joined_2 = df_joined.set_index('name').join(df_ks_2.set_index('title'))

# %%
df_joined_2.dropna()
# Out:
#                      backers_count  \
# "Street"                         2
# A Night In                      19
# Believe                        115
# Believe                          4
# Beyond The Wall                  9
# ...                            ...
# Withering Away                   3
# Working Title                   24
# Working Title                    0
# Worst Case Scenario             10
# Worst Case Scenario              1
#
#                                                                  blurb  \
# "Street"             "I want to offer street people and panhandlers...
# A Night In              Some people just shouldn't watch scary movies.
# Believe              A dramatic sci-fi short about two men whose li...
# Believe              Psychological Action Horror with live actors. ...
# Beyond The Wall      Student project featuring all student work. Th...
# ...                                                                ...
# ...
