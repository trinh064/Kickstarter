# %%
import numpy as np
import pandas as pd
import random

# %%
# new data to combine with initial data (Note: formatted differently from df_2018 data)
df_ks = pd.read_csv("../Data/kickstarter.csv")

# %%
# Cleaning
# 1. Delete the first column (i.e., the row id 'Unnamed')
del df_ks['Unnamed: 0']

# %%
# 2. Replace state string with numbers in df_sk
cleanup_nums = {"state": {"failed": 0, "successful": 1, "canceled" : -1, "undefined" : -1, "live" : -1, "suspended" : -1}}
df_ks.replace(cleanup_nums, inplace=True)

# %%
# 3. Remove Duplicate values
# 3a. Sort by the number of backers (assuming you'll have more backers)
df_ks_sorted = df_ks.sort_values(by='backers_count')
# 3b. Remove duplicates
df_ks_sorted.drop_duplicates(subset='id', keep='last', inplace=True)

# %%
# 4. Create new dataframe with the columns (that are not in 2018) = 
# id, backers_count, blurb, blurb_length, spotlight, staff_pick, location_state, location_displayable_name
df_ks_dropped = df_ks_sorted[['id','backers_count', 'blurb', 'blurb_length', 'spotlight', 'staff_pick', 'location_state', 'location_displayable_name']].sort_values(by='id')

# %%
df_ks_dropped.head()
# Out:
#            id  backers_count  \
# 343901   8624            737
# 212211  18520              4
# 11159   21109             11
# 62717   24380             18
# 34144   33867             42
#
#                                                     blurb  blurb_length  \
# 343901  A compact outdoor cooking set that you can use...            12
# 212211  Raising money to help my grandmother recover f...            24
# 11159   My work is performance based but I branch out ...            24
# 62717   A sanctuary for humans and felines alike! Come...            24
# 34144   Taste Makers is a socially conscious brand tha...            23
#
#         spotlight  staff_pick location_state location_displayable_name
# 343901       True        True             WV               Belgium, WV
# 212211      False       False             OH             Cleveland, OH
# 11159        True       False       Scotland                Dundee, UK
# 62717       False       False             IL           Bloomington, IL
# 34144       False        True             BC         Vancouver, Canada

# %%
# Read in other Data files
df_2018 = pd.read_csv("../Data/Cleaned/2018.csv", parse_dates= ['launched', 'deadline'])
# Rename ID to id
df_2018 = df_2018.rename(columns={"ID": "id"})

# %%
def time_since_last_project(series):
    # Return the time in hours
    return series.diff().dt.total_seconds() / 3600.

df = df_2018[['category', 'launched']].sort_values('launched')
timedeltas = df.groupby('category').transform(time_since_last_project)
timedeltas.head(20)
# Out:
#           launched
# 148129         NaN
# 281872         NaN
# 121357         NaN
# 284836         NaN
# 107424  137.130833
# 187060         NaN
# 302546  145.941111
# 205965         NaN
# 299605         NaN
# 240887         NaN
# 248799         NaN
# 28862          NaN
# 134191  101.581667
# 17159          NaN
# 197133         NaN
# 25378          NaN
# 52611          NaN
# 137932    0.010833
# 314790    6.715833
# 99802          NaN

# %%
# Final time since last project (in hours)
timedeltas = timedeltas.fillna(timedeltas.median()).reindex(df_ks.index)
timedeltas.head(10)
# Out:
#      launched
# 0  189.000278
# 1    5.592778
# 2    1.313611
# 3    0.635000
# 4    2.629722
# 5    0.367500
# 6   12.286111
# 7    1.372222
# 8    8.524444
# 9    0.015833

# %%
df_2018['hours_since_last_project'] = timedeltas['launched']
df_2018.head()
# Out:
#            id                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000014025                               Monarch Espresso Bar
#
#          category main_category currency   deadline     goal  \
# 0          Poetry    Publishing      GBP 2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD 2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD 2013-02-26  45000.0
# 3           Music         Music      USD 2012-04-16   5000.0
# 4     Restaurants          Food      USD 2016-04-01  50000.0
#
#              launched  pledged  state  backers country  usd pledged  \
# 0 2015-08-11 12:12:28      0.0      0        0      GB          0.0
# 1 2017-09-02 04:43:57   2421.0      0       15      US        100.0
# 2 2013-01-12 00:20:50    220.0      0        3      US        220.0
# 3 2012-03-17 03:24:11      1.0      0        1      US          1.0
# 4 2016-02-26 13:38:27  52375.0      1      224      US      52375.0
#
#    usd_pledged_real  usd_goal_real  hours_since_last_project
# 0               0.0        1533.95                189.000278
# 1            2421.0       30000.00                  5.592778
# 2             220.0       45000.00                  1.313611
# 3               1.0        5000.00                  0.635000
# 4           52375.0       50000.00                  2.629722

# %%
# Join the two tables on id
df_joined_ids = df_ks_dropped.set_index('id').join(df_2018.set_index('id'))

# %%
# Remove any rows that have a NaN in the name column
df_joined_ids = df_joined_ids.dropna();
df_joined_ids.head()
# Out:
#        backers_count                                              blurb  \
# id
# 18520              4  Raising money to help my grandmother recover f...
# 21109             11  My work is performance based but I branch out ...
# 24380             18  A sanctuary for humans and felines alike! Come...
# 33867             42  Taste Makers is a socially conscious brand tha...
# 39036             68  The BEST beef sticks, beef jerky and signature...
#
#        blurb_length  spotlight  staff_pick location_state  \
# id
# 18520            24      False       False             OH
# 21109            24       True       False       Scotland
# 24380            24      False       False             IL
# 33867            23      False        True             BC
# 39036            13       True       False             WI
#
#       location_displayable_name  \
# id
# 18520             Cleveland, OH
# 21109                Dundee, UK
# 24380           Bloomington, IL
# 33867         Vancouver, Canada
# 39036          Kronenwetter, WI
#
#                                                     name         category  \
# id
# 18520                                 Grandma's are Life      World Music
# 21109                                               Meta  Performance Art
# 24380  Puss N' Books: A relaxing cat cafe and bookstore.           Spaces
# 33867                            TASTE MAKERS BY TRISH P    Ready-to-wear
# 39036                          The Meat Candy Experience      Small Batch
#
#       main_category  ...     goal            launched  pledged state  backers  \
# id                   ...
# 18520         Music  ...  15000.0 2016-10-19 15:32:40     62.0   0.0      4.0
# 21109           Art  ...    150.0 2015-04-08 00:37:44    173.0   1.0     11.0
# 24380          Food  ...  20000.0 2015-10-27 16:25:33    776.0   0.0     18.0
# 33867       Fashion  ...  18000.0 2015-06-15 20:28:11   2798.0   0.0     42.0
# 39036          Food  ...   2500.0 2016-05-17 00:34:18   3239.0   1.0     68.0
#
#        country  usd pledged usd_pledged_real  usd_goal_real  \
# id
# 18520       US         0.00            62.00       15000.00
# 21109       GB       258.04           266.65         231.20
# 24380       US       776.00           776.00       20000.00
# 33867       CA      2271.72          2144.39       13795.22
# 39036       US      3239.00          3239.00        2500.00
#
#        hours_since_last_project
# id
# 18520                 66.078889
# 21109                 29.557500
# 24380                113.248611
# 33867                  2.419444
# 39036                  3.911389
#
# [5 rows x 22 columns]

# %%
# Convert Timestamps
df_joined_ids = df_joined_ids.assign(
                launch_hour=df_joined_ids.launched.dt.hour,
                launch_day=df_joined_ids.launched.dt.day,
                launch_month=df_joined_ids.launched.dt.month,
                launch_year=df_joined_ids.launched.dt.year)

df_joined_ids = df_joined_ids.assign(
                deadline_day=df_joined_ids.deadline.dt.day,
                deadline_month=df_joined_ids.deadline.dt.month,
                deadline_year=df_joined_ids.deadline.dt.year)

# %%
# Add column: project duration in days
#from datetime import datetime
df_joined_ids['launched'] = pd.to_datetime(df_joined_ids['launched']).dt.date
df_joined_ids['deadline'] = pd.to_datetime(df_joined_ids['deadline']).dt.date

df_joined_ids['duration_days'] = (df_joined_ids['deadline'] - df_joined_ids['launched']).dt.days

# %%
df_joined_ids.head(3)
# Out:
#        backers_count                                              blurb  \
# id
# 18520              4  Raising money to help my grandmother recover f...
# 21109             11  My work is performance based but I branch out ...
# 24380             18  A sanctuary for humans and felines alike! Come...
#
#        blurb_length  spotlight  staff_pick location_state  \
# id
# 18520            24      False       False             OH
# 21109            24       True       False       Scotland
# 24380            24      False       False             IL
#
#       location_displayable_name  \
# id
# 18520             Cleveland, OH
# 21109                Dundee, UK
# 24380           Bloomington, IL
#
#                                                     name         category  \
# id
# 18520                                 Grandma's are Life      World Music
# 21109                                               Meta  Performance Art
# 24380  Puss N' Books: A relaxing cat cafe and bookstore.           Spaces
#
#       main_category  ... usd_goal_real hours_since_last_project  launch_hour  \
# id                   ...
# 18520         Music  ...       15000.0                66.078889           15
# 21109           Art  ...         231.2                29.557500            0
# 24380          Food  ...       20000.0               113.248611           16
#
#       launch_day  launch_month  launch_year  deadline_day deadline_month  \
# id
# 18520         19            10         2016            18             11
# 21109          8             4         2015             6              5
# 24380         27            10         2015            26             11
#
#        deadline_year  duration_days
# id
# 18520           2016             30
# 21109           2015             28
# 24380           2015             30
#
# [3 rows x 30 columns]

# %%
# Drop Redundant Columns
df_joined_ids = df_joined_ids.drop(columns=['location_displayable_name'])
df_joined_ids = df_joined_ids.drop(columns=['backers'])
df_joined_ids = df_joined_ids.drop(columns=['usd pledged'])
df_joined_ids = df_joined_ids.drop(columns=['currency'])
df_joined_ids = df_joined_ids.drop(columns=['pledged'])
df_joined_ids = df_joined_ids.drop(columns=['goal'])
#df_joined_ids = df_joined_ids.drop(columns=['launched'])
#df_joined_ids = df_joined_ids.drop(columns=['deadline'])

# %%
df_joined_ids.head()
# Out:
#        backers_count                                              blurb  \
# id
# 18520              4  Raising money to help my grandmother recover f...
# 21109             11  My work is performance based but I branch out ...
# 24380             18  A sanctuary for humans and felines alike! Come...
# 33867             42  Taste Makers is a socially conscious brand tha...
# 39036             68  The BEST beef sticks, beef jerky and signature...
#
#        blurb_length  spotlight  staff_pick location_state  \
# id
# 18520            24      False       False             OH
# 21109            24       True       False       Scotland
# 24380            24      False       False             IL
# 33867            23      False        True             BC
# 39036            13       True       False             WI
#
#                                                     name         category  \
# id
# 18520                                 Grandma's are Life      World Music
# 21109                                               Meta  Performance Art
# 24380  Puss N' Books: A relaxing cat cafe and bookstore.           Spaces
# 33867                            TASTE MAKERS BY TRISH P    Ready-to-wear
# 39036                          The Meat Candy Experience      Small Batch
#
#       main_category    deadline  ... usd_goal_real  hours_since_last_project  \
# id                               ...
# 18520         Music  2016-11-18  ...      15000.00                 66.078889
# 21109           Art  2015-05-06  ...        231.20                 29.557500
# 24380          Food  2015-11-26  ...      20000.00                113.248611
# 33867       Fashion  2015-07-30  ...      13795.22                  2.419444
# 39036          Food  2016-07-01  ...       2500.00                  3.911389
#
#       launch_hour  launch_day  launch_month  launch_year  deadline_day  \
# id
# 18520          15          19            10         2016            18
# 21109           0           8             4         2015             6
# 24380          16          27            10         2015            26
# 33867          20          15             6         2015            30
# 39036           0          17             5         2016             1
#
#        deadline_month  deadline_year  duration_days
# id
# 18520              11           2016             30
# 21109               5           2015             28
# 24380              11           2015             30
# 33867               7           2015             45
# 39036               7           2016             45
#
# [5 rows x 24 columns]

# %%
df_joined_ids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 242630 entries, 18520 to 2147476221
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   backers_count             242630 non-null  int64
#  1   blurb                     242630 non-null  object
#  2   blurb_length              242630 non-null  int64
#  3   spotlight                 242630 non-null  bool
#  4   staff_pick                242630 non-null  bool
#  5   location_state            242630 non-null  object
#  6   name                      242630 non-null  object
#  7   category                  242630 non-null  object
#  8   main_category             242630 non-null  object
#  9   deadline                  242630 non-null  object
#  10  launched                  242630 non-null  object
#  11  state                     242630 non-null  float64
#  12  country                   242630 non-null  object
#  13  usd_pledged_real          242630 non-null  float64
#  14  usd_goal_real             242630 non-null  float64
#  15  hours_since_last_project  242630 non-null  float64
#  16  launch_hour               242630 non-null  int64
#  17  launch_day                242630 non-null  int64
#  18  launch_month              242630 non-null  int64
#  19  launch_year               242630 non-null  int64
#  20  deadline_day              242630 non-null  int64
#  21  deadline_month            242630 non-null  int64
#  22  deadline_year             242630 non-null  int64
#  23  duration_days             242630 non-null  int64
# dtypes: bool(2), float64(4), int64(10), object(8)
# memory usage: 43.0+ MB

# %%
df_joined_ids.to_csv("../Data/Cleaned/joined_data.csv", index = False)
