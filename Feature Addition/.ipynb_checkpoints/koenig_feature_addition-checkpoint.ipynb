# %% [markdown]
# # Feature Addition

# %%
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dense
import random
import numpy as np
import statistics
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from sklearn.preprocessing import LabelEncoder

# %%
rdata = pd.read_csv("../Data/Cleaned/2018.csv", parse_dates=['launched'])

# %%
rdata
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000014025                               Monarch Espresso Bar
# ...            ...                                                ...
# 331457   999975836              Homemade fresh dog food, Cleveland OH
# 331458   999977640                                          The Tribe
# 331459   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 331460   999987933                           BioDefense Education Kit
# 331461   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# ...

# %% [markdown]
# ## Time since last project in the same category
# code from:
# https://www.kaggle.com/matleonard/feature-generation

# %%
def time_since_last_project(series):
    # Return the time in hours
    return series.diff().dt.total_seconds() / 3600.

data = rdata[['category', 'launched']].sort_values('launched')
timedeltas = data.groupby('category').transform(time_since_last_project)
timedeltas.head(20)
# Out:
#           launched
# 148129         NaN
# 281872         NaN
# 121357         NaN
# 284836         NaN
# 107424  137.130833
# 187060         NaN
# 302546  145.941111
# 205965         NaN
# 299605         NaN
# 240887         NaN
# 248799         NaN
# 28862          NaN
# 134191  101.581667
# 17159          NaN
# 197133         NaN
# 25378          NaN
# 52611          NaN
# 137932    0.010833
# 314790    6.715833
# 99802          NaN

# %%
# Final time since last project
timedeltas = timedeltas.fillna(timedeltas.median()).reindex(rdata.index)
timedeltas.head(20)
# Out:
#       launched
# 0   189.000278
# 1     5.592778
# 2     1.313611
# 3     0.635000
# 4     2.629722
# 5     0.367500
# 6    12.286111
# 7     1.372222
# 8     8.524444
# 9     0.015833
# 10    9.884444
# 11    1.725556
# 12    3.806111
# 13    2.654167
# 14   26.531667
# 15   12.273611
# 16    9.288889
# 17    1.960556
# 18   89.228056
# 19    6.137778

# %% [markdown]
# # Exploration

# %%
rdata["launched"] = timedeltas
rdata.dropna(inplace = True)
rdata.shape
# Out:
# (331462, 15)

# %%
rdata["launched"].where(rdata["state"] == 1).mean()
# Out:
# 36.022912842970506

# %%
rdata["launched"].where(rdata["state"] == 0).mean()
# Out:
# 22.746490700866293

# %% [markdown]
# Number of projects in last week
#
# code from: https://www.kaggle.com/matleonard/feature-generation

# %%
rdata = pd.read_csv("../Data/Cleaned/2018.csv", parse_dates=['launched'])

# %%
launched = pd.Series(rdata.index, index=rdata.launched, name="count_7_days").sort_index()
launched.head(20)
# Out:
# launched
# 2009-04-21 21:02:48    148129
# 2009-04-23 00:07:53    281872
# 2009-04-24 21:52:03    121357
# 2009-04-25 17:36:21    284836
# 2009-04-27 14:10:39    107424
# 2009-04-28 13:55:41    187060
# 2009-04-29 02:04:21    302546
# 2009-04-29 02:58:50    205965
# 2009-04-29 05:26:32    299605
# 2009-04-29 06:43:44    240887
# 2009-04-29 13:52:03    248799
# 2009-04-29 22:08:13     28862
# 2009-04-29 23:11:15    134191
# 2009-04-30 01:32:55     17159
# 2009-04-30 07:14:06    197133
# 2009-04-30 22:10:30     25378
# 2009-04-30 22:22:43     52611
# 2009-04-30 22:23:22    137932
# 2009-05-01 05:06:19    314790
# 2009-05-01 14:22:21     99802
# Name: count_7_days, dtype: int64

# %%
count_7_days = launched.rolling('7d').count() - 1
print(count_7_days.head(20))

# Ignore records with broken launch dates
plt.plot(count_7_days[7:]);
plt.title("Number of projects launched over periods of 7 days");
# Out:
# launched
# 2009-04-21 21:02:48     0.0
# 2009-04-23 00:07:53     1.0
# 2009-04-24 21:52:03     2.0
# 2009-04-25 17:36:21     3.0
# 2009-04-27 14:10:39     4.0
# 2009-04-28 13:55:41     5.0
# 2009-04-29 02:04:21     5.0
# 2009-04-29 02:58:50     6.0
# 2009-04-29 05:26:32     7.0
# 2009-04-29 06:43:44     8.0
# 2009-04-29 13:52:03     9.0
# 2009-04-29 22:08:13    10.0
# 2009-04-29 23:11:15    11.0
# 2009-04-30 01:32:55    11.0
# 2009-04-30 07:14:06    12.0
# 2009-04-30 22:10:30    13.0
# 2009-04-30 22:22:43    14.0
# 2009-04-30 22:23:22    15.0
# 2009-05-01 05:06:19    16.0
# 2009-05-01 14:22:21    17.0
# Name: count_7_days, dtype: float64

# %%
count_7_days.index = launched.values
count_7_days = count_7_days.reindex(rdata.index)

# %%
rdata = rdata.join(count_7_days).head(10)

# %%
rdata["count_7_days"].where(rdata["state"] == 1).mean()
# Out:
# 942.6666666666666

# %%
rdata["count_7_days"].where(rdata["state"] == 0).mean()
# Out:
# 968.4285714285714
